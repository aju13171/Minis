# %%
# IMPORTS
import random as rnd
import numpy as np
import statistics as st

# %%
def debug_print(lista, titulo):
    print(titulo)
    for i in lista:
        print(i.fitness)

# %%
class individuo:
    def __init__(self, x1, x2):
        self.x1 = x1
        self.x2 = x2
        self.fitness = 0
    
    def set_fitness(self, f):
        self.fitness = f
        #print(self.fitness)
        
    def debug(self):
        s = "x1: "+ str(self.x1) + "\n" + "x2: "+ str(self.x2) + "\n" + "fitness: "+ str(self.fitness)
        return s

# %%
def pool_inicial(n_individuos, limsx1, limix1, limsx2, limix2, restr):
    population = []
    for i in range(n_individuos):
        x1 = round(rnd.random()*(limsx1 - limix1)+limix1, 1)
        limrx2 = restr(x1)
        limsx2 = min(limsx2,limrx2)
        x2 = round(rnd.random()*(limsx2 - limix2)+limix2, 1)
        ind = individuo(x1,x2)
        population.append(ind)
    #print("pool inicial", population)
    return population

# %%
def check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr):
    check_x1 = False
    check_x2 = False
    limrx2 = restr(x1)
    limsx2 = min(limsx2,limrx2)
    if(x1<limsx1 and x1>limix1):
        check_x1 = True
    if(check_x1):
        limrx2 = restr(x1)
        limsx2 = min(limsx2,limrx2)
        if(x2<limsx2 and x2>limix2):
            check_x2 = True
        
    return check_x1, check_x2

# %%
def fitness_calculation(population, fun):
    for i in population:
        #print("indv x1: ", i.x1, "indv x2: ", i.x2)
        i.set_fitness(fun(i.x1, i.x2))

# %%
def selection(population):
    pop_sorted = sorted(population, key=lambda x: x.fitness, reverse=True)
    #debug_print(pop_sorted, "sorted population: ")
    new_population = pop_sorted[:round(len(pop_sorted)/2)]
    #debug_print(new_population,"selection return: ")
    return new_population

# %%
def cross(population):
    new_population = []
    for i in population:
        for j in population:
            if(i != j):
                x1_heredada = i.x1
                x2_heredada = j.x2
                hijo = individuo(x1_heredada, x2_heredada)
                new_population.append(hijo)
    #new_population.append(individuo(population[-1].x1, population[0].x2))
    return new_population[:len(population)*2]

# %%
def mutation(population, limsx1, limix1, limsx2, limix2, restr):
    new_population = []
    for i in population:
        c_x1 = False
        c_x2 = False
        while(not(c_x1) and not(c_x2)):
            gen_mutar = rnd.randint(0,1)
            if(gen_mutar == 0):
                x1 = round(i.x1 + rnd.gauss(0, 0.001), 3)
                x2 = i.x2
            else:
                x1 = i.x1
                x2 = round(i.x2 + rnd.gauss(0, 0.001), 3)
            c = check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr)
            c_x1 = c[0]
            c_x2 = c[1]
        new_population.append(individuo(x1,x2))
    return new_population

# %%
def Optimo(fitness, n_individuos, limsx1, limix1, limsx2, limix2, restr, nmax, var):
    varianza = 1
    n = 0
    population = pool_inicial(n_individuos, limsx1, limix1, limsx2, limix2, restr)
    while(n < nmax):
        print("\n----> iteración: ", n)
        print("cant ind", len(population))
        #print("first item: ", population[len(population)-1].fitness)
        population = selection(population)
        #debug_print(population, "after selection")
        population = cross(population)
        #debug_print(population, "after cross")
        population = mutation(population, limsx1, limix1, limsx2, limix2, restr)
        fitness_calculation(population, fitness)
        #debug_print(population, "after mutation")
        fits = [i.fitness for i in population]
        #print("fits: ", fits)
        varianza = st.variance(fits[:round(len(fits)/2)])
        print("varianza",varianza)
        n += 1
        #print("fitness order first item: ", population[0].fitness)
    return population[0]

# %%
fitness = lambda x1,x2: -(x1)**2 - (x2)**2 + 5
restr = lambda x1: x1
pos = np.linspace(-5,5,100)

o = Optimo(fitness, 30, 5, -5, 5, -5, restr, 100, 0.2)
print("\n-------> RESULTADOS:")
print("x1: ",o.x1, "\tx2: ",o.x2)
print("fitness: ", o.fitness)
print("equation value: ", fitness(o.x1,o.x2))
# Out:
# ----> iteración:  0
# cant ind 30
# varianza 52.24470742432842
#
# ----> iteración:  1
# cant ind 30
# varianza 39.169783978147414
#
# ----> iteración:  2
# cant ind 30
# varianza 58.068859914290954
#
# ----> iteración:  3
# cant ind 30
# varianza 61.646411914743645
#
# ----> iteración:  4
# cant ind 30
# varianza 9.538314154285603e-05
#
# ----> iteración:  5
# cant ind 30
# varianza 3.569935978094856e-05
#
# ----> iteración:  6
# cant ind 30
# varianza 5.069037349523424e-05
#
# ----> iteración:  7
# cant ind 30
# varianza 4.247799135238392e-05
#
# ----> iteración:  8
# cant ind 30
# varianza 4.966223540952703e-05
#
# ----> iteración:  9
# cant ind 30
# varianza 2.456491149523735e-05
#
# ----> iteración:  10
# cant ind 30
# varianza 1.1903235123807127e-05
#
# ----> iteración:  11
# cant ind 30
# varianza 2.4893395780952682e-05
#
# ----> iteración:  12
# cant ind 30
# varianza 3.913228366666596e-05
#
# ----> iteración:  13
# cant ind 30
# varianza 4.125297195238264e-05
#
# ----> iteración:  14
# cant ind 30
# varianza 1.017415740000132e-05
#
# ----> iteración:  15
# cant ind 30
# varianza 4.171032098095099e-05
#
# ----> iteración:  16
# cant ind 30
# varianza 1.7299396409520906e-05
#
# ----> iteración:  17
# cant ind 30
# varianza 4.6989065552377654e-05
#
# ----> iteración:  18
# cant ind 30
# varianza 1.58848809714253e-05
#
# ----> iteración:  19
# cant ind 30
# varianza 2.7530738495242754e-05
#
# ----> iteración:  20
# cant ind 30
# varianza 2.0360127457147702e-05
#
# ----> iteración:  21
# cant ind 30
# varianza 2.6820125285715268e-05
#
# ----> iteración:  22
# cant ind 30
# varianza 1.174081625714074e-05
#
# ----> iteración:  23
# cant ind 30
# varianza 2.136520978094719e-05
#
# ----> iteración:  24
# cant ind 30
# varianza 1.525284671428093e-05
#
# ----> iteración:  25
# cant ind 30
# varianza 4.8866181428572885e-05
#
# ----> iteración:  26
# cant ind 30
# varianza 6.465418369523945e-05
#
# ----> iteración:  27
# cant ind 30
# varianza 2.0005636066664843e-05
#
# ----> iteración:  28
# cant ind 30
# varianza 1.7665698980948975e-05
#
# ----> iteración:  29
# cant ind 30
# varianza 2.36491844952351e-05
#
# ----> iteración:  30
# cant ind 30
# varianza 2.2558949638098074e-05
#
# ----> iteración:  31
# cant ind 30
# varianza 4.5124204257145835e-05
#
# ----> iteración:  32
# cant ind 30
# varianza 3.172295525714418e-05
#
# ----> iteración:  33
# cant ind 30
# varianza 5.712036566666551e-05
#
# ----> iteración:  34
# cant ind 30
# varianza 2.227209245713876e-05
#
# ----> iteración:  35
# cant ind 30
# varianza 3.656610635238122e-05
#
# ----> iteración:  36
# cant ind 30
# varianza 3.2204113980955986e-05
#
# ----> iteración:  37
# cant ind 30
# varianza 3.584500069524087e-05
#
# ----> iteración:  38
# cant ind 30
# varianza 2.043596545713711e-05
#
# ----> iteración:  39
# cant ind 30
# varianza 2.3623199685707745e-05
#
# ----> iteración:  40
# cant ind 30
# varianza 2.199746192381068e-05
#
# ----> iteración:  41
# cant ind 30
# varianza 5.780757598095577e-05
#
# ----> iteración:  42
# cant ind 30
# varianza 3.334239820952634e-05
#
# ----> iteración:  43
# cant ind 30
# varianza 3.4365283266665163e-05
#
# ----> iteración:  44
# cant ind 30
# varianza 4.506225638095342e-05
#
# ----> iteración:  45
# cant ind 30
# varianza 4.79990274571457e-05
#
# ----> iteración:  46
# cant ind 30
# varianza 5.285919711429239e-05
#
# ----> iteración:  47
# cant ind 30
# varianza 2.2796071780956274e-05
#
# ----> iteración:  48
# cant ind 30
# varianza 2.234531782857401e-05
#
# ----> iteración:  49
# cant ind 30
# varianza 1.993490469523597e-05
#
# ----> iteración:  50
# cant ind 30
# varianza 1.8913024028568963e-05
#
# ----> iteración:  51
# cant ind 30
# varianza 3.200807035238187e-05
#
# ----> iteración:  52
# cant ind 30
# varianza 2.370622600000239e-05
#
# ----> iteración:  53
# cant ind 30
# varianza 1.1570755828576548e-05
#
# ----> iteración:  54
# cant ind 30
# varianza 1.3022768923809105e-05
#
# ----> iteración:  55
# cant ind 30
# varianza 4.5208962171426766e-05
#
# ----> iteración:  56
# cant ind 30
# varianza 2.7443905638095486e-05
#
# ----> iteración:  57
# cant ind 30
# varianza 2.4961141695234224e-05
#
# ----> iteración:  58
# cant ind 30
# varianza 1.613364678095106e-05
#
# ----> iteración:  59
# cant ind 30
# varianza 1.8079098238099212e-05
#
# ----> iteración:  60
# cant ind 30
# varianza 2.6044886885717257e-05
#
# ----> iteración:  61
# cant ind 30
# varianza 4.328789338095041e-05
#
# ----> iteración:  62
# cant ind 30
# varianza 3.1153244495229765e-05
#
# ----> iteración:  63
# cant ind 30
# varianza 2.5073620923803268e-05
#
# ----> iteración:  64
# cant ind 30
# varianza 3.1854963838099505e-05
#
# ----> iteración:  65
# cant ind 30
# varianza 2.6066553685720117e-05
#
# ----> iteración:  66
# cant ind 30
# varianza 3.916569255237671e-05
#
# ----> iteración:  67
# cant ind 30
# varianza 6.477836135237755e-05
#
# ----> iteración:  68
# cant ind 30
# varianza 4.2246148980951065e-05
#
# ----> iteración:  69
# cant ind 30
# varianza 7.180599078095082e-05
#
# ----> iteración:  70
# cant ind 30
# varianza 6.639694585714424e-05
#
# ----> iteración:  71
# cant ind 30
# varianza 5.568986083809637e-05
#
# ----> iteración:  72
# cant ind 30
# varianza 3.098511823809783e-05
#
# ----> iteración:  73
# cant ind 30
# varianza 9.950422392381454e-05
#
# ----> iteración:  74
# cant ind 30
# varianza 9.438092160000429e-05
#
# ----> iteración:  75
# cant ind 30
# varianza 5.991405142856467e-05
#
# ----> iteración:  76
# cant ind 30
# varianza 3.3507321523814974e-05
#
# ----> iteración:  77
# cant ind 30
# varianza 2.318990220953059e-05
#
# ----> iteración:  78
# cant ind 30
# varianza 1.3734395114283237e-05
#
# ----> iteración:  79
# cant ind 30
# varianza 1.452255806666388e-05
#
# ----> iteración:  80
# cant ind 30
# varianza 3.8555778123810055e-05
#
# ----> iteración:  81
# cant ind 30
# varianza 2.6962514495239134e-05
#
# ----> iteración:  82
# cant ind 30
# varianza 2.1746081495241634e-05
#
# ----> iteración:  83
# cant ind 30
# varianza 3.34604760952417e-05
#
# ----> iteración:  84
# cant ind 30
# varianza 1.6804072409522873e-05
#
# ----> iteración:  85
# cant ind 30
# varianza 2.647879749523318e-05
#
# ----> iteración:  86
# cant ind 30
# varianza 2.7085479352382514e-05
#
# ----> iteración:  87
# cant ind 30
# varianza 3.161703855237876e-05
#
# ----> iteración:  88
# cant ind 30
# varianza 1.8692720066670234e-05
#
# ----> iteración:  89
# cant ind 30
# varianza 2.2306188409523974e-05
#
# ----> iteración:  90
# cant ind 30
# varianza 5.3283552495238366e-05
#
# ----> iteración:  91
# cant ind 30
# varianza 1.9076020171426065e-05
#
# ----> iteración:  92
# cant ind 30
# varianza 2.640210374285804e-05
#
# ----> iteración:  93
# cant ind 30
# varianza 7.727619463809305e-05
#
# ----> iteración:  94
# cant ind 30
# varianza 5.821138620952471e-05
#
# ----> iteración:  95
# cant ind 30
# varianza 3.4952028266661927e-05
#
# ----> iteración:  96
# cant ind 30
# varianza 2.2743166095239957e-05
#
# ----> iteración:  97
# cant ind 30
# varianza 3.892682152381402e-05
#
# ----> iteración:  98
# cant ind 30
# varianza 5.66563181714305e-05
#
# ----> iteración:  99
# cant ind 30
# varianza 3.0998375971427714e-05
#
# -------> RESULTADOS:
# x1:  -0.069 	x2:  2.625
# fitness:  -1.8953860000000002
# equation value:  -1.8953860000000002
