# %%
# IMPORTS
import random as rnd
import numpy as np
import statistics as st

# %%
def debug_print(lista, titulo):
    print(titulo)
    for i in lista:
        print(i.fitness)

# %%
class individuo:
    def __init__(self, x1, x2):
        self.x1 = x1
        self.x2 = x2
        self.fitness = 0
    
    def set_fitness(self, f):
        self.fitness = f
        #print(self.fitness)
        
    def debug(self):
        s = "x1: "+ str(self.x1) + "\n" + "x2: "+ str(self.x2) + "\n" + "fitness: "+ str(self.fitness)
        return s

# %%
def pool_inicial(n_individuos, limsx1, limix1, limsx2, limix2, restr):
    population = []
    for i in range(n_individuos):
        x1 = round(rnd.random()*(limsx1 - limix1)+limix1, 1)
        limrx2 = restr(x1)
        limsx2 = min(limsx2,limrx2)
        x2 = round(rnd.random()*(limsx2 - limix2)+limix2, 1)
        ind = individuo(x1,x2)
        population.append(ind)
    #print("pool inicial", population)
    return population

# %%
def check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr):
    check_x1 = False
    check_x2 = False
    limrx2 = restr(x1)
    limsx2 = min(limsx2,limrx2)
    if(x1<limsx1 and x1>limix1):
        check_x1 = True
    if(check_x1):
        limrx2 = restr(x1)
        limsx2 = min(limsx2,limrx2)
        if(x2<limsx2 and x2>limix2):
            check_x2 = True
        
    return check_x1, check_x2

# %%
def fitness_calculation(population, fun):
    for i in population:
        #print("indv x1: ", i.x1, "indv x2: ", i.x2)
        i.set_fitness(fun(i.x1, i.x2))

# %%
def selection(population):
    pop_sorted = sorted(population, key=lambda x: x.fitness, reverse=True)
    #debug_print(pop_sorted, "sorted population: ")
    new_population = pop_sorted[:round(len(pop_sorted)/2)]
    #debug_print(new_population,"selection return: ")
    return new_population

# %%
def cross(population):
    new_population = []
    for i in population:
        for j in population:
            if(i != j):
                x1_heredada = i.x1
                x2_heredada = j.x2
                hijo = individuo(x1_heredada, x2_heredada)
                new_population.append(hijo)
    #new_population.append(individuo(population[-1].x1, population[0].x2))
    return new_population[:len(population)*2]

# %%
def mutation(population, limsx1, limix1, limsx2, limix2, restr):
    new_population = []
    for i in population:
        c_x1 = False
        c_x2 = False
        while(not(c_x1) and not(c_x2)):
            gen_mutar = rnd.randint(0,1)
            if(gen_mutar == 0):
                x1 = round(i.x1 + rnd.gauss(0, 0.1), 3)
                x2 = i.x2
            else:
                x1 = i.x1
                x2 = round(i.x2 + rnd.gauss(0, 0.1), 3)
            c = check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr)
            c_x1 = c[0]
            c_x2 = c[1]
        new_population.append(individuo(x1,x2))
    return new_population

# %%
def Optimo(fitness, n_individuos, limsx1, limix1, limsx2, limix2, restr, nmax):
    varianza = 1
    n = 0
    population = pool_inicial(n_individuos, limsx1, limix1, limsx2, limix2, restr)
    fitness_calculation(population, fitness)
    while(n < nmax):
        print("\n----> iteración: ", n)
        print("cant ind", len(population))
        print("first item: ", population[len(population)-1].x1, " ", population[len(population)-1].x2)
        population = selection(population)
        #debug_print(population, "after selection")
        population = cross(population)
        #debug_print(population, "after cross")
        population = mutation(population, limsx1, limix1, limsx2, limix2, restr)
        fitness_calculation(population, fitness)
        #debug_print(population, "after mutation")
        n += 1
        print("fitness order first item: ", population[0].fitness)
    return population[0]

# %%
fitness = lambda x1,x2: -(x1)**2 - (x2)**2 + 5
restr = lambda x1: x1
pos = np.linspace(-5,5,100)

o = Optimo(fitness, 6, 5, -5, 5, -5, restr, 100)
print("RESULTADOS: ")
print("x1: ",o.x1, "\tx2: ",o.x2)
print("fitness: ", o.fitness)
# Out:
# ----> iteración:  0
# cant ind 6
# first item:  -3.8   -5.0
# fitness order first item:  -2.4192360000000015
#
# ----> iteración:  1
# cant ind 6
# first item:  4.7   -2.278
# fitness order first item:  -1.5692250000000003
#
# ----> iteración:  2
# cant ind 6
# first item:  -1.096   -2.2
# fitness order first item:  0.1313500000000003
#
# ----> iteración:  3
# cant ind 6
# first item:  -0.998   -1.891
# fitness order first item:  0.5140030000000007
#
# ----> iteración:  4
# cant ind 6
# first item:  -1.05   -1.891
# fitness order first item:  0.4456030000000002
#
# ----> iteración:  5
# cant ind 6
# first item:  -1.05   -1.768
# fitness order first item:  0.27827499999999983
#
# ----> iteración:  6
# cant ind 6
# first item:  -1.001   -1.84
# fitness order first item:  1.0578839999999996
#
# ----> iteración:  7
# cant ind 6
# first item:  -1.147   -1.883
# fitness order first item:  1.1722989999999998
#
# ----> iteración:  8
# cant ind 6
# first item:  -0.639   -1.623
# fitness order first item:  1.3579589999999997
#
# ----> iteración:  9
# cant ind 6
# first item:  -0.924   -1.852
# fitness order first item:  1.366968
#
# ----> iteración:  10
# cant ind 6
# first item:  -0.916   -1.581
# fitness order first item:  2.0783799999999997
#
# ----> iteración:  11
# cant ind 6
# first item:  -0.916   -1.561
# fitness order first item:  2.1755319999999996
#
# ----> iteración:  12
# cant ind 6
# first item:  -0.677   -1.602
# fitness order first item:  2.127247
#
# ----> iteración:  13
# cant ind 6
# first item:  -0.648   -1.596
# fitness order first item:  1.814855
#
# ----> iteración:  14
# cant ind 6
# first item:  -0.508   -1.394
# fitness order first item:  2.915388
#
# ----> iteración:  15
# cant ind 6
# first item:  -0.534   -1.394
# fitness order first item:  3.03451
#
# ----> iteración:  16
# cant ind 6
# first item:  -0.534   -1.551
# fitness order first item:  3.334102
#
# ----> iteración:  17
# cant ind 6
# first item:  -0.343   -1.394
# fitness order first item:  3.239715
#
# ----> iteración:  18
# cant ind 6
# first item:  -0.208   -1.309
# fitness order first item:  3.296323
#
# ----> iteración:  19
# cant ind 6
# first item:  -0.521   -1.294
# fitness order first item:  3.1974
#
# ----> iteración:  20
# cant ind 6
# first item:  -0.199   -1.252
# fitness order first item:  3.7546359999999996
#
# ----> iteración:  21
# cant ind 6
# first item:  -0.199   -1.189
# fitness order first item:  3.821808
#
# ----> iteración:  22
# cant ind 6
# first item:  -0.23   -1.092
# fitness order first item:  3.9380230000000003
#
# ----> iteración:  23
# cant ind 6
# first item:  0.055   -1.084
# fitness order first item:  3.8335359999999996
#
# ----> iteración:  24
# cant ind 6
# first item:  -0.05   -1.128
# fitness order first item:  4.125144
#
# ----> iteración:  25
# cant ind 6
# first item:  -0.056   -1.068
# fitness order first item:  3.8568759999999997
#
# ----> iteración:  26
# cant ind 6
# first item:  0.078   -1.012
# fitness order first item:  4.127019
#
# ----> iteración:  27
# cant ind 6
# first item:  -0.035   -0.934
# fitness order first item:  4.127203
#
# ----> iteración:  28
# cant ind 6
# first item:  -0.057   -0.912
# fitness order first item:  4.127644
#
# ----> iteración:  29
# cant ind 6
# first item:  0.087   -0.934
# fitness order first item:  4.323227
#
# ----> iteración:  30
# cant ind 6
# first item:  -0.033   -0.822
# fitness order first item:  4.306284
#
# ----> iteración:  31
# cant ind 6
# first item:  -0.033   -0.919
# fitness order first item:  4.578799
#
# ----> iteración:  32
# cant ind 6
# first item:  -0.033   -0.779
# fitness order first item:  4.575651
#
# ----> iteración:  33
# cant ind 6
# first item:  -0.033   -0.679
# fitness order first item:  4.38819
#
# ----> iteración:  34
# cant ind 6
# first item:  -0.033   -0.646
# fitness order first item:  4.572502
#
# ----> iteración:  35
# cant ind 6
# first item:  0.185   -0.762
# fitness order first item:  4.694595
#
# ----> iteración:  36
# cant ind 6
# first item:  0.066   -0.539
# fitness order first item:  4.817683
#
# ----> iteración:  37
# cant ind 6
# first item:  -0.015   -0.426
# fitness order first item:  4.938343
#
# ----> iteración:  38
# cant ind 6
# first item:  0.075   -0.209
# fitness order first item:  4.909694
#
# ----> iteración:  39
# cant ind 6
# first item:  0.065   -0.163
# fitness order first item:  4.96222
#
# ----> iteración:  40
# cant ind 6
# first item:  0.096   -0.151
# fitness order first item:  4.932255
#
# ----> iteración:  41
# cant ind 6
# first item:  0.012   -0.016
# fitness order first item:  4.983055
#
# ----> iteración:  42
# cant ind 6
# first item:  0.124   -0.068
# fitness order first item:  4.991756
#
# ----> iteración:  43
# cant ind 6
# first item:  0.111   0.005
# fitness order first item:  4.984387
#
# ----> iteración:  44
# cant ind 6
# first item:  0.17   -0.023
# fitness order first item:  4.99344
#
# ----> iteración:  45
# cant ind 6
# first item:  -0.022   -0.096
# fitness order first item:  4.95131
#
# ----> iteración:  46
# cant ind 6
# first item:  0.041   -0.027
# fitness order first item:  4.956422
#
# ----> iteración:  47
# cant ind 6
# first item:  0.012   0.002
# fitness order first item:  4.996096
#
# ----> iteración:  48
# cant ind 6
# first item:  0.162   -0.04
# fitness order first item:  4.992711
#
# ----> iteración:  49
# cant ind 6
# first item:  0.048   0.197
# fitness order first item:  4.964256
#
# ----> iteración:  50
# cant ind 6
# first item:  -0.121   -0.091
# fitness order first item:  4.998739
#
# ----> iteración:  51
# cant ind 6
# first item:  -0.084   -0.055
# fitness order first item:  4.996374
#
# ----> iteración:  52
# cant ind 6
# first item:  0.026   0.006
# fitness order first item:  4.999324
#
# ----> iteración:  53
# cant ind 6
# first item:  0.061   -0.067
# fitness order first item:  4.976283
#
# ----> iteración:  54
# cant ind 6
# first item:  0.035   0.035
# fitness order first item:  4.981086
#
# ----> iteración:  55
# cant ind 6
# first item:  0.095   0.051
# fitness order first item:  4.989943
#
# ----> iteración:  56
# cant ind 6
# first item:  0.095   0.004
# fitness order first item:  4.990971
#
# ----> iteración:  57
# cant ind 6
# first item:  0.095   0.267
# fitness order first item:  4.976734
#
# ----> iteración:  58
# cant ind 6
# first item:  0.105   0.071
# fitness order first item:  4.998759
#
# ----> iteración:  59
# cant ind 6
# first item:  0.077   -0.042
# fitness order first item:  4.99992
#
# ----> iteración:  60
# cant ind 6
# first item:  -0.035   0.009
# fitness order first item:  4.999798
#
# ----> iteración:  61
# cant ind 6
# first item:  -0.029   -0.254
# fitness order first item:  4.980558
#
# ----> iteración:  62
# cant ind 6
# first item:  -0.1   -0.093
# fitness order first item:  4.958155
#
# ----> iteración:  63
# cant ind 6
# first item:  -0.033   -0.027
# fitness order first item:  4.998895
#
# ----> iteración:  64
# cant ind 6
# first item:  -0.117   0.056
# fitness order first item:  4.973272
#
# ----> iteración:  65
# cant ind 6
# first item:  -0.064   0.042
# fitness order first item:  4.967343
#
# ----> iteración:  66
# cant ind 6
# first item:  -0.343   0.062
# fitness order first item:  4.99606
#
# ----> iteración:  67
# cant ind 6
# first item:  -0.13   0.014
# fitness order first item:  4.98454
#
# ----> iteración:  68
# cant ind 6
# first item:  -0.195   0.045
# fitness order first item:  4.981816
#
# ----> iteración:  69
# cant ind 6
# first item:  -0.082   0.071
# fitness order first item:  4.988092
#
# ----> iteración:  70
# cant ind 6
# first item:  -0.082   -0.02
# fitness order first item:  4.988364
#
# ----> iteración:  71
# cant ind 6
# first item:  -0.047   0.088
# fitness order first item:  4.977603
#
# ----> iteración:  72
# cant ind 6
# first item:  0.159   0.014
# fitness order first item:  4.941867
#
# ----> iteración:  73
# cant ind 6
# first item:  0.003   0.062
# fitness order first item:  4.94803
#
# ----> iteración:  74
# cant ind 6
# first item:  -0.08   0.032
# fitness order first item:  4.992919
#
# ----> iteración:  75
# cant ind 6
# first item:  -0.091   0.005
# fitness order first item:  4.993575
#
# ----> iteración:  76
# cant ind 6
# first item:  -0.146   0.005
# fitness order first item:  4.999491
#
# ----> iteración:  77
# cant ind 6
# first item:  0.06   0.058
# fitness order first item:  4.99926
#
# ----> iteración:  78
# cant ind 6
# first item:  0.074   0.102
# fitness order first item:  4.972291
#
# ----> iteración:  79
# cant ind 6
# first item:  -0.067   0.097
# fitness order first item:  4.99926
#
# ----> iteración:  80
# cant ind 6
# first item:  0.022   -0.095
# fitness order first item:  4.968846
#
# ----> iteración:  81
# cant ind 6
# first item:  0.071   0.026
# fitness order first item:  4.984311
#
# ----> iteración:  82
# cant ind 6
# first item:  0.038   -0.054
# fitness order first item:  4.991891
#
# ----> iteración:  83
# cant ind 6
# first item:  0.02   0.003
# fitness order first item:  4.998742
#
# ----> iteración:  84
# cant ind 6
# first item:  0.022   0.003
# fitness order first item:  4.995643
#
# ----> iteración:  85
# cant ind 6
# first item:  -0.013   -0.003
# fitness order first item:  4.98751
#
# ----> iteración:  86
# cant ind 6
# first item:  -0.064   -0.158
# fitness order first item:  4.997696
#
# ----> iteración:  87
# cant ind 6
# first item:  0.1   0.032
# fitness order first item:  4.978675
#
# ----> iteración:  88
# cant ind 6
# first item:  0.092   -0.216
# fitness order first item:  4.995886
#
# ----> iteración:  89
# cant ind 6
# first item:  -0.266   -0.106
# fitness order first item:  4.986099
#
# ----> iteración:  90
# cant ind 6
# first item:  -0.211   0.115
# fitness order first item:  4.993375
#
# ----> iteración:  91
# cant ind 6
# first item:  -0.068   -0.049
# fitness order first item:  4.99224
#
# ----> iteración:  92
# cant ind 6
# first item:  0.088   -0.056
# fitness order first item:  4.933435
#
# ----> iteración:  93
# cant ind 6
# first item:  0.095   -0.089
# fitness order first item:  4.996891
#
# ----> iteración:  94
# cant ind 6
# first item:  0.095   -0.04
# fitness order first item:  4.992376
#
# ----> iteración:  95
# cant ind 6
# first item:  0.058   -0.097
# fitness order first item:  4.988075
#
# ----> iteración:  96
# cant ind 6
# first item:  -0.056   0.03
# fitness order first item:  4.99224
#
# ----> iteración:  97
# cant ind 6
# first item:  -0.105   -0.041
# fitness order first item:  4.991179
#
# ----> iteración:  98
# cant ind 6
# first item:  -0.088   0.103
# fitness order first item:  4.994059
#
# ----> iteración:  99
# cant ind 6
# first item:  0.027   0.03
# fitness order first item:  4.998843
# RESULTADOS:
# x1:  0.031 	x2:  0.014
# fitness:  4.998843
