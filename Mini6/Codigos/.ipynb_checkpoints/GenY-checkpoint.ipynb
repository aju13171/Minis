# %%
# IMPORTS
import random as rnd
import numpy as np
import statistics as st

# %%
def debug_print(lista, titulo):
    print(titulo)
    for i in lista:
        print(i.fitness)

# %%
class individuo:
    def __init__(self, x1, x2):
        self.x1 = x1
        self.x2 = x2
        self.fitness = 0
    
    def set_fitness(self, f):
        self.fitness = f
        #print(self.fitness)
        
    def debug(self):
        s = "x1: "+ str(self.x1) + "\n" + "x2: "+ str(self.x2) + "\n" + "fitness: "+ str(self.fitness)
        return s

# %%
def pool_inicial(n_individuos, limsx1, limix1, limsx2, limix2, restr):
    population = []
    for i in range(n_individuos):
        x1 = round(rnd.random()*(limsx1 - limix1)+limix1, 3)
        limrx2 = restr(x1)
        limsx2 = min(limsx2,limrx2)
        x2 = round(rnd.random()*(limsx2 - limix2)+limix2, 3)
        ind = individuo(x1,x2)
        population.append(ind)
    #print("pool inicial", population)
    return population

# %%
def check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr):
    check_x1 = False
    check_x2 = False
    limrx2 = restr(x1)
    limsx2 = min(limsx2,limrx2)
    if(x1<limsx1 and x1>limix1):
        check_x1 = True
    if(check_x1):
        limrx2 = restr(x1)
        limsx2 = min(limsx2,limrx2)
        if(x2<limsx2 and x2>limix2):
            check_x2 = True    
    return check_x1, check_x2

# %%
def fitness_calculation(population, fun):
    for i in population:
        #print("indv x1: ", i.x1, "indv x2: ", i.x2)
        i.set_fitness(fun(i.x1, i.x2))

# %%
def selection(population):
    pop_sorted = sorted(population, key=lambda x: x.fitness, reverse=True)
    #debug_print(pop_sorted, "sorted population: ")
    new_population = pop_sorted[:round(len(pop_sorted)/2)]
    #debug_print(new_population,"selection return: ")
    return new_population

# %%
def cross(population):
    new_population = []
    for i in population:
        for j in population:
            if(i != j):
                x1_heredada = i.x1
                x2_heredada = j.x2
                hijo = individuo(x1_heredada, x2_heredada)
                new_population.append(hijo)
    #new_population.append(individuo(population[-1].x1, population[0].x2))
    return new_population[:len(population)*2]

# %%
def mutation(population, limsx1, limix1, limsx2, limix2, restr):
    new_population = []
    for i in population:
        c_x1 = False
        c_x2 = False
        n = 0
        while(c_x1 == False or c_x2 == False):
            gen_mutar = rnd.randint(0,1)
            if(n<10):
                if(gen_mutar == 0):
                    x1 = round(i.x1 + rnd.gauss(0, 0.1), 3)
                    x2 = i.x2
                else:
                    x1 = i.x1
                    x2 = round(i.x2 + rnd.gauss(0, 0.1), 3)
            else:
                if(gen_mutar == 0):
                    x1 = round(rnd.random()*(limsx1 - limix1)+limix1, 3)
                    x2 = i.x2
                else:
                    x1 = i.x1
                    x2 = round(rnd.random()*(limsx2 - limix2)+limix2, 3)
            
            n += 1
            c = check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr)
            c_x1 = c[0]
            c_x2 = c[1]
        new_population.append(individuo(x1,x2))
    return new_population

# %%
def Optimo(fitness, n_individuos, limsx1, limix1, limsx2, limix2, restr, nmax):
    varianza = 1
    n = 0
    population = pool_inicial(n_individuos, limsx1, limix1, limsx2, limix2, restr)
    fitness_calculation(population, fitness)
    while(n < nmax):
        print("\n----> iteración: ", n)
        print("cant ind", len(population))
        print("first item: ", population[len(population)-1].x1, " ", population[len(population)-1].x2)
        population = selection(population)
        #debug_print(population, "after selection")
        population = cross(population)
        #debug_print(population, "after cross")
        population = mutation(population, limsx1, limix1, limsx2, limix2, restr)
        fitness_calculation(population, fitness)
        #debug_print(population, "after mutation")
        n += 1
        print("fitness order first item: ", population[0].fitness)
    return population[0]

# %%
fitness = lambda x1,x2: -(x1)**2 - (x2)**2 + 5
restr = lambda x1: x1
pos = np.linspace(-5,5,100)

o = Optimo(fitness, 30, 5, -5, 5, -5, restr, 100)
print("RESULTADOS: ")
print("x1: ",o.x1, "\tx2: ",o.x2)
print("fitness: ", o.fitness)
# Out:
# ----> iteración:  0
# cant ind 30
# first item:  4.664   -4.718
# fitness order first item:  1.6989910000000004
#
# ----> iteración:  1
# cant ind 30
# first item:  -0.738   -1.535
# fitness order first item:  3.66547
#
# ----> iteración:  2
# cant ind 30
# first item:  -0.738   -1.137
# fitness order first item:  3.041375
#
# ----> iteración:  3
# cant ind 30
# first item:  -0.738   -1.088
# fitness order first item:  3.493056
#
# ----> iteración:  4
# cant ind 30
# first item:  -0.887   -1.053
# fitness order first item:  3.843463
#
# ----> iteración:  5
# cant ind 30
# first item:  -0.593   -0.696
# fitness order first item:  3.876728
#
# ----> iteración:  6
# cant ind 30
# first item:  -0.651   -0.947
# fitness order first item:  4.160728000000001
#
# ----> iteración:  7
# cant ind 30
# first item:  -0.554   -0.714
# fitness order first item:  4.235692
#
# ----> iteración:  8
# cant ind 30
# first item:  -0.597   -0.732
# fitness order first item:  4.302552
#
# ----> iteración:  9
# cant ind 30
# first item:  -0.295   -0.596
# fitness order first item:  4.572248
#
# ----> iteración:  10
# cant ind 30
# first item:  -0.36   -0.529
# fitness order first item:  4.737904
#
# ----> iteración:  11
# cant ind 30
# first item:  -0.392   -0.543
# fitness order first item:  4.7167259999999995
#
# ----> iteración:  12
# cant ind 30
# first item:  -0.295   -0.377
# fitness order first item:  4.69264
#
# ----> iteración:  13
# cant ind 30
# first item:  -0.295   -0.352
# fitness order first item:  4.831084
#
# ----> iteración:  14
# cant ind 30
# first item:  -0.34   -0.396
# fitness order first item:  4.937835
#
# ----> iteración:  15
# cant ind 30
# first item:  -0.212   -0.247
# fitness order first item:  4.90327
#
# ----> iteración:  16
# cant ind 30
# first item:  -0.095   -0.247
# fitness order first item:  4.936131
#
# ----> iteración:  17
# cant ind 30
# first item:  -0.059   -0.183
# fitness order first item:  4.999383
#
# ----> iteración:  18
# cant ind 30
# first item:  -0.079   -0.089
# fitness order first item:  4.999558
#
# ----> iteración:  19
# cant ind 30
# first item:  0.019   -0.157
# fitness order first item:  4.994662
#
# ----> iteración:  20
# cant ind 30
# first item:  0.23   0.009
# fitness order first item:  4.996126
#
# ----> iteración:  21
# cant ind 30
# first item:  0.019   -0.031
# fitness order first item:  4.999452
#
# ----> iteración:  22
# cant ind 30
# first item:  0.019   -0.082
# fitness order first item:  4.999495
#
# ----> iteración:  23
# cant ind 30
# first item:  0.019   -0.036
# fitness order first item:  4.99891
#
# ----> iteración:  24
# cant ind 30
# first item:  -0.008   -0.245
# fitness order first item:  4.99275
#
# ----> iteración:  25
# cant ind 30
# first item:  0.019   -0.063
# fitness order first item:  4.999414
#
# ----> iteración:  26
# cant ind 30
# first item:  0.094   0.008
# fitness order first item:  4.99963
#
# ----> iteración:  27
# cant ind 30
# first item:  0.019   0.012
# fitness order first item:  4.990663
#
# ----> iteración:  28
# cant ind 30
# first item:  0.019   -0.066
# fitness order first item:  4.999856
#
# ----> iteración:  29
# cant ind 30
# first item:  0.215   -0.012
# fitness order first item:  4.999831
#
# ----> iteración:  30
# cant ind 30
# first item:  0.028   -0.108
# fitness order first item:  4.999851
#
# ----> iteración:  31
# cant ind 30
# first item:  0.007   -0.2
# fitness order first item:  4.996764
#
# ----> iteración:  32
# cant ind 30
# first item:  0.001   -0.01
# fitness order first item:  4.995643
#
# ----> iteración:  33
# cant ind 30
# first item:  -0.01   -0.054
# fitness order first item:  4.986414
#
# ----> iteración:  34
# cant ind 30
# first item:  0.035   -0.019
# fitness order first item:  4.973819
#
# ----> iteración:  35
# cant ind 30
# first item:  -0.003   -0.174
# fitness order first item:  4.899703
#
# ----> iteración:  36
# cant ind 30
# first item:  -0.005   -0.021
# fitness order first item:  4.994791
#
# ----> iteración:  37
# cant ind 30
# first item:  0.0   -0.008
# fitness order first item:  4.999375
#
# ----> iteración:  38
# cant ind 30
# first item:  0.004   -0.009
# fitness order first item:  4.996494
#
# ----> iteración:  39
# cant ind 30
# first item:  0.0   -0.214
# fitness order first item:  4.999595
#
# ----> iteración:  40
# cant ind 30
# first item:  -0.005   -0.077
# fitness order first item:  4.990195
#
# ----> iteración:  41
# cant ind 30
# first item:  -0.003   -0.22
# fitness order first item:  4.996515
#
# ----> iteración:  42
# cant ind 30
# first item:  0.002   -0.111
# fitness order first item:  4.992256
#
# ----> iteración:  43
# cant ind 30
# first item:  0.16   -0.0
# fitness order first item:  4.998847
#
# ----> iteración:  44
# cant ind 30
# first item:  0.011   -0.132
# fitness order first item:  4.987335
#
# ----> iteración:  45
# cant ind 30
# first item:  0.09   -0.004
# fitness order first item:  4.9995
#
# ----> iteración:  46
# cant ind 30
# first item:  0.01   -0.022
# fitness order first item:  4.999683
#
# ----> iteración:  47
# cant ind 30
# first item:  0.085   -0.022
# fitness order first item:  4.994904
#
# ----> iteración:  48
# cant ind 30
# first item:  -0.004   -0.163
# fitness order first item:  4.998039
#
# ----> iteración:  49
# cant ind 30
# first item:  0.011   -0.121
# fitness order first item:  4.956735
#
# ----> iteración:  50
# cant ind 30
# first item:  0.005   -0.042
# fitness order first item:  4.98956
#
# ----> iteración:  51
# cant ind 30
# first item:  0.164   -0.006
# fitness order first item:  4.999647
#
# ----> iteración:  52
# cant ind 30
# first item:  0.059   -0.003
# fitness order first item:  4.99992
#
# ----> iteración:  53
# cant ind 30
# first item:  0.008   -0.128
# fitness order first item:  4.990959
#
# ----> iteración:  54
# cant ind 30
# first item:  0.016   -0.038
# fitness order first item:  4.992942
#
# ----> iteración:  55
# cant ind 30
# first item:  0.015   -0.015
# fitness order first item:  4.965235
#
# ----> iteración:  56
# cant ind 30
# first item:  0.05   -0.008
# fitness order first item:  4.999695
#
# ----> iteración:  57
# cant ind 30
# first item:  -0.01   -0.016
# fitness order first item:  4.990174
#
# ----> iteración:  58
# cant ind 30
# first item:  -0.007   -0.045
# fitness order first item:  4.925967
#
# ----> iteración:  59
# cant ind 30
# first item:  0.015   -0.023
# fitness order first item:  4.999199
#
# ----> iteración:  60
# cant ind 30
# first item:  0.017   -0.075
# fitness order first item:  4.997966
#
# ----> iteración:  61
# cant ind 30
# first item:  0.015   -0.154
# fitness order first item:  4.999847
#
# ----> iteración:  62
# cant ind 30
# first item:  0.209   -0.0
# fitness order first item:  4.963891
#
# ----> iteración:  63
# cant ind 30
# first item:  0.196   -0.012
# fitness order first item:  4.997575
#
# ----> iteración:  64
# cant ind 30
# first item:  0.127   -0.02
# fitness order first item:  4.997944
#
# ----> iteración:  65
# cant ind 30
# first item:  0.085   -0.034
# fitness order first item:  4.995486
#
# ----> iteración:  66
# cant ind 30
# first item:  0.002   -0.031
# fitness order first item:  4.988875
#
# ----> iteración:  67
# cant ind 30
# first item:  0.024   -0.122
# fitness order first item:  4.975439
#
# ----> iteración:  68
# cant ind 30
# first item:  0.01   -0.001
# fitness order first item:  4.998235
#
# ----> iteración:  69
# cant ind 30
# first item:  0.096   -0.001
# fitness order first item:  4.996984
#
# ----> iteración:  70
# cant ind 30
# first item:  0.06   -0.019
# fitness order first item:  4.999584
#
# ----> iteración:  71
# cant ind 30
# first item:  0.176   -0.02
# fitness order first item:  4.999975
#
# ----> iteración:  72
# cant ind 30
# first item:  0.107   -0.019
# fitness order first item:  4.969875
#
# ----> iteración:  73
# cant ind 30
# first item:  0.004   -0.06
# fitness order first item:  4.995
#
# ----> iteración:  74
# cant ind 30
# first item:  0.005   -0.211
# fitness order first item:  4.998622
#
# ----> iteración:  75
# cant ind 30
# first item:  0.023   -0.004
# fitness order first item:  4.987719
#
# ----> iteración:  76
# cant ind 30
# first item:  0.069   -0.02
# fitness order first item:  4.996131
#
# ----> iteración:  77
# cant ind 30
# first item:  0.003   -0.07
# fitness order first item:  4.99998
#
# ----> iteración:  78
# cant ind 30
# first item:  0.118   -0.025
# fitness order first item:  4.994359
#
# ----> iteración:  79
# cant ind 30
# first item:  0.005   -0.114
# fitness order first item:  4.977399
#
# ----> iteración:  80
# cant ind 30
# first item:  -0.015   -0.02
# fitness order first item:  4.99982
#
# ----> iteración:  81
# cant ind 30
# first item:  0.007   -0.01
# fitness order first item:  4.996455
#
# ----> iteración:  82
# cant ind 30
# first item:  0.082   -0.008
# fitness order first item:  4.92075
#
# ----> iteración:  83
# cant ind 30
# first item:  0.1   -0.017
# fitness order first item:  4.999803
#
# ----> iteración:  84
# cant ind 30
# first item:  0.013   -0.328
# fitness order first item:  4.99135
#
# ----> iteración:  85
# cant ind 30
# first item:  0.131   -0.014
# fitness order first item:  4.995579
#
# ----> iteración:  86
# cant ind 30
# first item:  0.102   -0.014
# fitness order first item:  4.998855
#
# ----> iteración:  87
# cant ind 30
# first item:  0.014   -0.125
# fitness order first item:  4.99623
#
# ----> iteración:  88
# cant ind 30
# first item:  0.052   -0.014
# fitness order first item:  4.979836
#
# ----> iteración:  89
# cant ind 30
# first item:  0.036   0.0
# fitness order first item:  4.999915
#
# ----> iteración:  90
# cant ind 30
# first item:  0.004   -0.013
# fitness order first item:  4.99983
#
# ----> iteración:  91
# cant ind 30
# first item:  -0.012   -0.013
# fitness order first item:  4.999623
#
# ----> iteración:  92
# cant ind 30
# first item:  -0.012   -0.02
# fitness order first item:  4.983084
#
# ----> iteración:  93
# cant ind 30
# first item:  0.066   -0.009
# fitness order first item:  4.993734
#
# ----> iteración:  94
# cant ind 30
# first item:  0.004   -0.105
# fitness order first item:  4.95672
#
# ----> iteración:  95
# cant ind 30
# first item:  0.017   -0.004
# fitness order first item:  4.999899
#
# ----> iteración:  96
# cant ind 30
# first item:  0.061   0.003
# fitness order first item:  4.999899
#
# ----> iteración:  97
# cant ind 30
# first item:  0.005   -0.123
# fitness order first item:  4.9851
#
# ----> iteración:  98
# cant ind 30
# first item:  0.066   -0.005
# fitness order first item:  4.995631
#
# ----> iteración:  99
# cant ind 30
# first item:  0.021   -0.043
# fitness order first item:  4.973707
# RESULTADOS:
# x1:  0.162 	x2:  0.007
# fitness:  4.973707

# %% [markdown]
# # Task 1
# ## Función:
# $$f(x_1,x_2) = 15x_1 + 30x_2 + 4x_1x_2 - 2x_1^2 - 4x_2^3$$
#
# ## Restricciones:
# $$x_1 + 2x_2 \leq 30$$
# $$x_1 \geq 0, x_2 \geq 0$$

# %%
fitness = lambda x1,x2: (15*x1)+(30*x2)+(4*x1*x2)-(2*(x1**2))-(4*(x2**2))
restr = lambda x1: 15 - (x1/2)
o = Optimo(fitness, 15, 40, 0, 40, 0, restr, 100)
print("RESULTADOS: ")
print("x1: ",o.x1, "\tx2: ",o.x2)
print("fitness: ", o.fitness)
# Out:
# ----> iteración:  0
# cant ind 15
# first item:  17.594   -0.474
# fitness order first item:  134.309772
#
# ----> iteración:  1
# cant ind 16
# first item:  17.594   3.236
# fitness order first item:  246.77691199999998
#
# ----> iteración:  2
# cant ind 16
# first item:  10.268   7.136
# fitness order first item:  253.3770700000001
#
# ----> iteración:  3
# cant ind 16
# first item:  10.368   7.641
# fitness order first item:  255.01597999999998
#
# ----> iteración:  4
# cant ind 16
# first item:  10.461   7.633
# fitness order first item:  253.27166
#
# ----> iteración:  5
# cant ind 16
# first item:  10.386   7.672
# fitness order first item:  256.179916
#
# ----> iteración:  6
# cant ind 16
# first item:  10.322   7.796
# fitness order first item:  257.71540400000004
#
# ----> iteración:  7
# cant ind 16
# first item:  10.703   8.117
# fitness order first item:  256.74894199999994
#
# ----> iteración:  8
# cant ind 16
# first item:  10.592   8.117
# fitness order first item:  257.5403660000001
#
# ----> iteración:  9
# cant ind 16
# first item:  10.592   7.933
# fitness order first item:  260.54075000000006
#
# ----> iteración:  10
# cant ind 16
# first item:  10.764   8.287
# fitness order first item:  259.8912
#
# ----> iteración:  11
# cant ind 16
# first item:  10.72   8.21
# fitness order first item:  261.28045399999996
#
# ----> iteración:  12
# cant ind 16
# first item:  10.802   8.235
# fitness order first item:  261.68765599999995
#
# ----> iteración:  13
# cant ind 16
# first item:  11.068   8.336
# fitness order first item:  263.283678
#
# ----> iteración:  14
# cant ind 16
# first item:  10.938   8.443
# fitness order first item:  264.1962140000001
#
# ----> iteración:  15
# cant ind 16
# first item:  11.139   8.487
# fitness order first item:  264.867542
#
# ----> iteración:  16
# cant ind 16
# first item:  11.139   8.334
# fitness order first item:  264.2140540000001
#
# ----> iteración:  17
# cant ind 16
# first item:  11.252   8.552
# fitness order first item:  265.57996600000007
#
# ----> iteración:  18
# cant ind 16
# first item:  11.279   8.58
# fitness order first item:  265.70630199999994
#
# ----> iteración:  19
# cant ind 16
# first item:  11.279   8.759
# fitness order first item:  266.36175000000014
#
# ----> iteración:  20
# cant ind 16
# first item:  11.347   8.998
# fitness order first item:  266.47443999999996
#
# ----> iteración:  21
# cant ind 16
# first item:  11.347   8.946
# fitness order first item:  268.0129339999999
#
# ----> iteración:  22
# cant ind 16
# first item:  11.386   9.081
# fitness order first item:  267.6952799999999
#
# ----> iteración:  23
# cant ind 16
# first item:  11.535   8.946
# fitness order first item:  269.51339199999995
#
# ----> iteración:  24
# cant ind 16
# first item:  11.474   9.102
# fitness order first item:  269.58311000000003
#
# ----> iteración:  25
# cant ind 16
# first item:  11.761   9.107
# fitness order first item:  269.399774
#
# ----> iteración:  26
# cant ind 16
# first item:  11.781   9.107
# fitness order first item:  269.8166300000001
#
# ----> iteración:  27
# cant ind 16
# first item:  11.792   9.101
# fitness order first item:  269.50927599999994
#
# ----> iteración:  28
# cant ind 16
# first item:  11.77   8.946
# fitness order first item:  178.89283
#
# ----> iteración:  29
# cant ind 16
# first item:  11.86   9.053
# fitness order first item:  269.594038
#
# ----> iteración:  30
# cant ind 16
# first item:  11.828   8.982
# fitness order first item:  269.8279
#
# ----> iteración:  31
# cant ind 16
# first item:  11.608   9.064
# fitness order first item:  269.8624299999999
#
# ----> iteración:  32
# cant ind 16
# first item:  11.756   9.069
# fitness order first item:  269.93327600000003
#
# ----> iteración:  33
# cant ind 16
# first item:  11.871   9.06
# fitness order first item:  268.77337599999987
#
# ----> iteración:  34
# cant ind 16
# first item:  11.75   9.06
# fitness order first item:  269.96869999999996
#
# ----> iteración:  35
# cant ind 16
# first item:  11.958   9.016
# fitness order first item:  269.6015000000001
#
# ----> iteración:  36
# cant ind 16
# first item:  11.921   9.016
# fitness order first item:  269.928062
#
# ----> iteración:  37
# cant ind 16
# first item:  11.887   8.955
# fitness order first item:  269.58575
#
# ----> iteración:  38
# cant ind 16
# first item:  11.795   9.005
# fitness order first item:  268.9013659999999
#
# ----> iteración:  39
# cant ind 16
# first item:  12.094   8.88
# fitness order first item:  269.60205399999995
#
# ----> iteración:  40
# cant ind 16
# first item:  11.951   8.949
# fitness order first item:  269.684318
#
# ----> iteración:  41
# cant ind 16
# first item:  12.026   8.893
# fitness order first item:  269.2645419999999
#
# ----> iteración:  42
# cant ind 16
# first item:  12.062   8.795
# fitness order first item:  269.9783980000001
#
# ----> iteración:  43
# cant ind 16
# first item:  12.035   8.974
# fitness order first item:  269.59359799999993
#
# ----> iteración:  44
# cant ind 16
# first item:  12.043   8.974
# fitness order first item:  269.60594199999997
#
# ----> iteración:  45
# cant ind 16
# first item:  11.874   8.975
# fitness order first item:  269.89829999999984
#
# ----> iteración:  46
# cant ind 16
# first item:  12.043   8.886
# fitness order first item:  269.90003
#
# ----> iteración:  47
# cant ind 16
# first item:  12.02   8.966
# fitness order first item:  269.8695160000001
#
# ----> iteración:  48
# cant ind 16
# first item:  12.06   8.949
# fitness order first item:  269.78868400000005
#
# ----> iteración:  49
# cant ind 16
# first item:  12.06   8.855
# fitness order first item:  269.6554359999999
#
# ----> iteración:  50
# cant ind 16
# first item:  12.019   8.949
# fitness order first item:  269.74304
#
# ----> iteración:  51
# cant ind 16
# first item:  12.07   8.739
# fitness order first item:  269.50840000000005
#
# ----> iteración:  52
# cant ind 16
# first item:  11.903   8.97
# fitness order first item:  269.0504600000001
#
# ----> iteración:  53
# cant ind 16
# first item:  12.113   8.862
# fitness order first item:  269.92678400000005
#
# ----> iteración:  54
# cant ind 16
# first item:  12.072   8.948
# fitness order first item:  269.86533400000013
#
# ----> iteración:  55
# cant ind 16
# first item:  12.079   8.901
# fitness order first item:  269.5280300000001
#
# ----> iteración:  56
# cant ind 16
# first item:  11.938   8.941
# fitness order first item:  269.7518059999998
#
# ----> iteración:  57
# cant ind 16
# first item:  12.082   8.954
# fitness order first item:  269.32756000000006
#
# ----> iteración:  58
# cant ind 16
# first item:  12.072   8.925
# fitness order first item:  269.09207599999996
#
# ----> iteración:  59
# cant ind 16
# first item:  12.082   8.903
# fitness order first item:  269.419054
#
# ----> iteración:  60
# cant ind 16
# first item:  11.932   8.937
# fitness order first item:  269.5815
#
# ----> iteración:  61
# cant ind 16
# first item:  12.109   8.822
# fitness order first item:  269.06239600000004
#
# ----> iteración:  62
# cant ind 16
# first item:  12.036   8.904
# fitness order first item:  269.73715
#
# ----> iteración:  63
# cant ind 16
# first item:  12.052   8.955
# fitness order first item:  269.67609200000004
#
# ----> iteración:  64
# cant ind 16
# first item:  12.052   8.892
# fitness order first item:  268.75679600000007
#
# ----> iteración:  65
# cant ind 16
# first item:  12.052   8.816
# fitness order first item:  269.8145660000001
#
# ----> iteración:  66
# cant ind 16
# first item:  12.113   8.9
# fitness order first item:  269.51767
#
# ----> iteración:  67
# cant ind 16
# first item:  12.108   8.944
# fitness order first item:  269.2303579999999
#
# ----> iteración:  68
# cant ind 16
# first item:  12.076   8.944
# fitness order first item:  269.813224
#
# ----> iteración:  69
# cant ind 16
# first item:  12.063   8.939
# fitness order first item:  268.25582200000014
#
# ----> iteración:  70
# cant ind 16
# first item:  12.026   8.915
# fitness order first item:  269.74842399999994
#
# ----> iteración:  71
# cant ind 16
# first item:  11.982   8.966
# fitness order first item:  268.9924059999999
#
# ----> iteración:  72
# cant ind 16
# first item:  12.037   8.86
# fitness order first item:  269.165006
#
# ----> iteración:  73
# cant ind 16
# first item:  11.977   8.958
# fitness order first item:  269.42552600000005
#
# ----> iteración:  74
# cant ind 16
# first item:  12.021   8.981
# fitness order first item:  269.59319200000004
#
# ----> iteración:  75
# cant ind 16
# first item:  11.863   8.981
# fitness order first item:  269.6176699999999
#
# ----> iteración:  76
# cant ind 16
# first item:  11.97   8.906
# fitness order first item:  268.88607
#
# ----> iteración:  77
# cant ind 16
# first item:  11.97   8.938
# fitness order first item:  269.15750999999995
#
# ----> iteración:  78
# cant ind 16
# first item:  11.985   8.929
# fitness order first item:  269.5761999999999
#
# ----> iteración:  79
# cant ind 16
# first item:  11.967   8.997
# fitness order first item:  269.6643800000001
#
# ----> iteración:  80
# cant ind 16
# first item:  11.957   8.977
# fitness order first item:  269.963884
#
# ----> iteración:  81
# cant ind 16
# first item:  11.869   9.003
# fitness order first item:  269.59175
#
# ----> iteración:  82
# cant ind 16
# first item:  11.979   8.977
# fitness order first item:  269.8796
#
# ----> iteración:  83
# cant ind 16
# first item:  12.13   8.906
# fitness order first item:  269.7745719999999
#
# ----> iteración:  84
# cant ind 16
# first item:  12.006   8.977
# fitness order first item:  269.78956400000004
#
# ----> iteración:  85
# cant ind 16
# first item:  12.006   8.798
# fitness order first item:  269.168222
#
# ----> iteración:  86
# cant ind 16
# first item:  12.03   8.777
# fitness order first item:  269.78257599999995
#
# ----> iteración:  87
# cant ind 16
# first item:  12.043   8.961
# fitness order first item:  269.57863
#
# ----> iteración:  88
# cant ind 16
# first item:  12.043   8.852
# fitness order first item:  269.745372
#
# ----> iteración:  89
# cant ind 16
# first item:  12.105   8.904
# fitness order first item:  269.73341999999997
#
# ----> iteración:  90
# cant ind 16
# first item:  12.109   8.933
# fitness order first item:  269.458758
#
# ----> iteración:  91
# cant ind 16
# first item:  12.109   8.943
# fitness order first item:  269.527104
#
# ----> iteración:  92
# cant ind 16
# first item:  11.941   8.952
# fitness order first item:  223.14405999999997
#
# ----> iteración:  93
# cant ind 16
# first item:  11.997   8.974
# fitness order first item:  269.82924399999996
#
# ----> iteración:  94
# cant ind 16
# first item:  11.998   8.747
# fitness order first item:  268.749004
#
# ----> iteración:  95
# cant ind 16
# first item:  12.028   8.918
# fitness order first item:  268.73322800000005
#
# ----> iteración:  96
# cant ind 16
# first item:  11.985   8.982
# fitness order first item:  269.69083200000006
#
# ----> iteración:  97
# cant ind 16
# first item:  12.011   8.964
# fitness order first item:  269.201212
#
# ----> iteración:  98
# cant ind 16
# first item:  11.963   8.961
# fitness order first item:  269.6305999999999
#
# ----> iteración:  99
# cant ind 16
# first item:  12.008   8.924
# fitness order first item:  269.91766
# RESULTADOS:
# x1:  12.068 	x2:  8.957
# fitness:  269.91766

# %% [markdown]
# # Task 2
# ## Función:
# $$z = 3x_1 + 5x_2$$
# ## Restricciones:
# $$x_1 \leq 4$$
# $$2x_2 \leq 12$$
# $$3x_1 + 2x_2 \leq 18$$
# $$x_1 >= 0, x_2 \geq 0$$

# %%
fitness = lambda x1,x2: (3*x1) + (5*x2)
restr = lambda x1: (18.0/2.0) - (3.0/2.0)*x1
o = Optimo(fitness, 15, 4, 0, 6, 0, restr, 100)
print("RESULTADOS: ")
print("x1: ",o.x1, "\tx2: ",o.x2)
print("fitness: ", o.fitness)
# Out:
# ----> iteración:  0
# cant ind 15
# first item:  0.795   2.805
# fitness order first item:  19.299000000000003
#
# ----> iteración:  1
# cant ind 16
# first item:  1.49   2.453
# fitness order first item:  22.208
#
# ----> iteración:  2
# cant ind 16
# first item:  2.915   2.895
# fitness order first item:  25.764
#
# ----> iteración:  3
# cant ind 16
# first item:  2.922   3.396
# fitness order first item:  26.958
#
# ----> iteración:  4
# cant ind 16
# first item:  3.045   3.598
# fitness order first item:  28.328000000000003
#
# ----> iteración:  5
# cant ind 16
# first item:  3.225   3.604
# fitness order first item:  28.968
#
# ----> iteración:  6
# cant ind 16
# first item:  3.134   3.721
# fitness order first item:  28.937
#
# ----> iteración:  7
# cant ind 16
# first item:  3.359   3.914
# fitness order first item:  29.825
#
# ----> iteración:  8
# cant ind 16
# first item:  3.359   3.928
# fitness order first item:  29.931
#
# ----> iteración:  9
# cant ind 16
# first item:  3.167   4.014
# fitness order first item:  29.781
#
# ----> iteración:  10
# cant ind 16
# first item:  3.307   4.014
# fitness order first item:  29.894999999999996
#
# ----> iteración:  11
# cant ind 16
# first item:  3.234   4.023
# fitness order first item:  29.568
#
# ----> iteración:  12
# cant ind 16
# first item:  3.145   4.017
# fitness order first item:  29.841
#
# ----> iteración:  13
# cant ind 16
# first item:  3.307   3.998
# fitness order first item:  29.651
#
# ----> iteración:  14
# cant ind 16
# first item:  3.277   4.031
# fitness order first item:  29.927999999999997
#
# ----> iteración:  15
# cant ind 16
# first item:  3.253   4.038
# fitness order first item:  30.023000000000003
#
# ----> iteración:  16
# cant ind 16
# first item:  3.301   3.963
# fitness order first item:  30.079
#
# ----> iteración:  17
# cant ind 16
# first item:  3.209   4.033
# fitness order first item:  29.857
#
# ----> iteración:  18
# cant ind 16
# first item:  3.292   3.935
# fitness order first item:  29.819000000000003
#
# ----> iteración:  19
# cant ind 16
# first item:  3.298   3.81
# fitness order first item:  29.895
#
# ----> iteración:  20
# cant ind 16
# first item:  3.244   4.037
# fitness order first item:  30.017999999999997
#
# ----> iteración:  21
# cant ind 16
# first item:  3.293   3.983
# fitness order first item:  29.436
#
# ----> iteración:  22
# cant ind 16
# first item:  3.274   4.026
# fitness order first item:  29.597
#
# ----> iteración:  23
# cant ind 16
# first item:  3.234   4.021
# fitness order first item:  29.408
#
# ----> iteración:  24
# cant ind 16
# first item:  3.083   4.031
# fitness order first item:  29.777
#
# ----> iteración:  25
# cant ind 16
# first item:  3.271   4.018
# fitness order first item:  29.669
#
# ----> iteración:  26
# cant ind 16
# first item:  3.227   4.018
# fitness order first item:  29.875999999999998
#
# ----> iteración:  27
# cant ind 16
# first item:  3.27   4.018
# fitness order first item:  30.034
#
# ----> iteración:  28
# cant ind 16
# first item:  3.285   4.013
# fitness order first item:  29.399
#
# ----> iteración:  29
# cant ind 16
# first item:  3.139   4.039
# fitness order first item:  29.965
#
# ----> iteración:  30
# cant ind 16
# first item:  3.308   3.861
# fitness order first item:  28.714999999999996
#
# ----> iteración:  31
# cant ind 16
# first item:  3.261   4.002
# fitness order first item:  29.612000000000002
#
# ----> iteración:  32
# cant ind 16
# first item:  3.285   4.008
# fitness order first item:  29.251
#
# ----> iteración:  33
# cant ind 16
# first item:  3.175   3.986
# fitness order first item:  29.935
#
# ----> iteración:  34
# cant ind 16
# first item:  3.326   3.974
# fitness order first item:  28.677999999999997
#
# ----> iteración:  35
# cant ind 16
# first item:  3.272   4.022
# fitness order first item:  29.815
#
# ----> iteración:  36
# cant ind 16
# first item:  3.243   4.044
# fitness order first item:  30.054
#
# ----> iteración:  37
# cant ind 16
# first item:  3.249   4.05
# fitness order first item:  29.724999999999998
#
# ----> iteración:  38
# cant ind 16
# first item:  3.268   3.955
# fitness order first item:  30.194999999999997
#
# ----> iteración:  39
# cant ind 16
# first item:  3.098   4.071
# fitness order first item:  29.249999999999996
#
# ----> iteración:  40
# cant ind 16
# first item:  3.192   4.076
# fitness order first item:  29.93
#
# ----> iteración:  41
# cant ind 16
# first item:  3.26   4.072
# fitness order first item:  29.32
#
# ----> iteración:  42
# cant ind 16
# first item:  3.275   3.938
# fitness order first item:  30.015
#
# ----> iteración:  43
# cant ind 16
# first item:  3.12   4.072
# fitness order first item:  29.833000000000002
#
# ----> iteración:  44
# cant ind 16
# first item:  3.261   3.835
# fitness order first item:  30.061
#
# ----> iteración:  45
# cant ind 16
# first item:  3.263   4.076
# fitness order first item:  29.692
#
# ----> iteración:  46
# cant ind 16
# first item:  3.265   4.076
# fitness order first item:  29.887
#
# ----> iteración:  47
# cant ind 16
# first item:  3.169   4.102
# fitness order first item:  29.618000000000002
#
# ----> iteración:  48
# cant ind 16
# first item:  3.254   4.096
# fitness order first item:  29.638
#
# ----> iteración:  49
# cant ind 16
# first item:  3.17   4.1
# fitness order first item:  29.519000000000002
#
# ----> iteración:  50
# cant ind 16
# first item:  3.225   4.071
# fitness order first item:  30.118000000000002
#
# ----> iteración:  51
# cant ind 16
# first item:  3.175   4.104
# fitness order first item:  29.963
#
# ----> iteración:  52
# cant ind 16
# first item:  3.201   4.098
# fitness order first item:  30.302999999999997
#
# ----> iteración:  53
# cant ind 16
# first item:  3.201   4.189
# fitness order first item:  29.848
#
# ----> iteración:  54
# cant ind 16
# first item:  3.201   4.077
# fitness order first item:  30.238
#
# ----> iteración:  55
# cant ind 16
# first item:  3.188   4.165
# fitness order first item:  30.398
#
# ----> iteración:  56
# cant ind 16
# first item:  3.188   4.116
# fitness order first item:  30.360999999999997
#
# ----> iteración:  57
# cant ind 16
# first item:  3.154   4.078
# fitness order first item:  30.336
#
# ----> iteración:  58
# cant ind 16
# first item:  3.2   4.18
# fitness order first item:  30.049999999999997
#
# ----> iteración:  59
# cant ind 16
# first item:  3.161   4.18
# fitness order first item:  30.540999999999997
#
# ----> iteración:  60
# cant ind 16
# first item:  3.194   4.131
# fitness order first item:  30.201999999999998
#
# ----> iteración:  61
# cant ind 16
# first item:  3.196   4.202
# fitness order first item:  30.603
#
# ----> iteración:  62
# cant ind 16
# first item:  3.035   4.202
# fitness order first item:  30.253999999999998
#
# ----> iteración:  63
# cant ind 16
# first item:  3.038   4.224
# fitness order first item:  30.68
#
# ----> iteración:  64
# cant ind 16
# first item:  3.097   4.207
# fitness order first item:  30.229999999999997
#
# ----> iteración:  65
# cant ind 16
# first item:  3.091   4.209
# fitness order first item:  30.409
#
# ----> iteración:  66
# cant ind 16
# first item:  3.193   4.172
# fitness order first item:  30.733999999999998
#
# ----> iteración:  67
# cant ind 16
# first item:  3.163   4.255
# fitness order first item:  30.388999999999996
#
# ----> iteración:  68
# cant ind 16
# first item:  3.188   4.183
# fitness order first item:  30.407999999999998
#
# ----> iteración:  69
# cant ind 16
# first item:  3.163   4.208
# fitness order first item:  30.113999999999997
#
# ----> iteración:  70
# cant ind 16
# first item:  3.101   4.217
# fitness order first item:  30.249000000000002
#
# ----> iteración:  71
# cant ind 16
# first item:  3.163   4.172
# fitness order first item:  30.200000000000003
#
# ----> iteración:  72
# cant ind 16
# first item:  3.03   4.24
# fitness order first item:  30.727999999999998
#
# ----> iteración:  73
# cant ind 16
# first item:  3.151   4.221
# fitness order first item:  30.676
#
# ----> iteración:  74
# cant ind 16
# first item:  3.152   4.265
# fitness order first item:  30.747999999999998
#
# ----> iteración:  75
# cant ind 16
# first item:  3.147   4.254
# fitness order first item:  30.523000000000003
#
# ----> iteración:  76
# cant ind 16
# first item:  3.133   4.271
# fitness order first item:  30.721000000000004
#
# ----> iteración:  77
# cant ind 16
# first item:  3.136   4.176
# fitness order first item:  30.544000000000004
#
# ----> iteración:  78
# cant ind 16
# first item:  3.142   4.255
# fitness order first item:  30.360999999999997
#
# ----> iteración:  79
# cant ind 16
# first item:  3.135   4.255
# fitness order first item:  30.951
#
# ----> iteración:  80
# cant ind 16
# first item:  3.147   4.226
# fitness order first item:  30.133999999999997
#
# ----> iteración:  81
# cant ind 16
# first item:  3.046   4.32
# fitness order first item:  30.912
#
# ----> iteración:  82
# cant ind 16
# first item:  3.052   4.308
# fitness order first item:  30.527
#
# ----> iteración:  83
# cant ind 16
# first item:  3.081   4.264
# fitness order first item:  30.755999999999997
#
# ----> iteración:  84
# cant ind 16
# first item:  3.048   4.302
# fitness order first item:  30.727000000000004
#
# ----> iteración:  85
# cant ind 16
# first item:  3.096   4.33
# fitness order first item:  30.596999999999998
#
# ----> iteración:  86
# cant ind 16
# first item:  3.077   4.33
# fitness order first item:  30.557999999999996
#
# ----> iteración:  87
# cant ind 16
# first item:  3.077   4.146
# fitness order first item:  31.072
#
# ----> iteración:  88
# cant ind 16
# first item:  3.069   4.323
# fitness order first item:  30.722
#
# ----> iteración:  89
# cant ind 16
# first item:  3.071   4.315
# fitness order first item:  30.418999999999997
#
# ----> iteración:  90
# cant ind 16
# first item:  3.084   4.336
# fitness order first item:  30.080999999999996
#
# ----> iteración:  91
# cant ind 16
# first item:  3.101   4.299
# fitness order first item:  31.039
#
# ----> iteración:  92
# cant ind 16
# first item:  2.975   4.361
# fitness order first item:  30.858999999999995
#
# ----> iteración:  93
# cant ind 16
# first item:  3.084   4.28
# fitness order first item:  30.705000000000002
#
# ----> iteración:  94
# cant ind 16
# first item:  3.052   4.281
# fitness order first item:  30.931000000000004
#
# ----> iteración:  95
# cant ind 16
# first item:  3.036   4.406
# fitness order first item:  30.866
#
# ----> iteración:  96
# cant ind 16
# first item:  3.052   4.402
# fitness order first item:  31.226
#
# ----> iteración:  97
# cant ind 16
# first item:  3.035   4.364
# fitness order first item:  30.971999999999998
#
# ----> iteración:  98
# cant ind 16
# first item:  2.913   4.395
# fitness order first item:  31.237000000000002
#
# ----> iteración:  99
# cant ind 16
# first item:  2.967   4.414
# fitness order first item:  30.152
# RESULTADOS:
# x1:  3.039 	x2:  4.207
# fitness:  30.152

# %% [markdown]
# # Task 3
# ## Función:
# $$f(x_1,x_2) = 5x_1 - x_1^2 + 8x_2 - 2x_2^2$$
# ## Restricciones:
# $$3x_1 + 2x_2 \leq 6$$
# $$x_1 \geq 0, x_2 \geq 0$$

# %%
fitness = lambda x1,x2: (5*x1) - (x1**2) + (8*x2) - (2*(x2**2))
restr = lambda x1: (6.0/2.0) - (3.0/2.0)*x1
o = Optimo(fitness, 15, 20, 0, 20, 0, restr, 100)
print("RESULTADOS: ")
print("x1: ",o.x1, "\tx2: ",o.x2)
print("fitness: ", o.fitness)
# Out:
# ----> iteración:  0
# cant ind 15
# first item:  5.749   -4.652
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-661-5ab6ac8379c4> in <module>
#       1 fitness = lambda x1,x2: (5*x1) - (x1**2) + (8*x2) - (2*(x2**2))
#       2 restr = lambda x1: (6.0/2.0) - (3.0/2.0)*x1
# ----> 3 o = Optimo(fitness, 15, 20, 0, 20, 0, restr, 100)
#       4 print("RESULTADOS: ")
#       5 print("x1: ",o.x1, "\tx2: ",o.x2)
#
# <ipython-input-643-6ac7f022419c> in Optimo(fitness, n_individuos, limsx1, limix1, limsx2, limix2, restr, nmax)
#      12         population = cross(population)
#      13         #debug_print(population, "after cross")
# ---> 14         population = mutation(population, limsx1, limix1, limsx2, limix2, restr)
#      15         fitness_calculation(population, fitness)
#      16         #debug_print(population, "after mutation")
#
# <ipython-input-642-01a1fd2e1eb1> in mutation(population, limsx1, limix1, limsx2, limix2, restr)
#      22                     x2 = round(rnd.random()*(limsx2 - limix2)+limix2, 3)
#      23
# ---> 24             n += 1
#      25             c = check_mutation(x1, x2, limsx1, limix1, limsx2, limix2, restr)
#      26             c_x1 = c[0]
#
# KeyboardInterrupt:
